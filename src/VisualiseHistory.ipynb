# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import seaborn as sns

from UserHistory import StreamingHistory
sns.set_theme()

# %%
test = StreamingHistory(
        [
            "/Users/iansnyder/Desktop/Projects/Spotify_Proj/Data/MyData/StreamingHistory0.json",
            "/Users/iansnyder/Desktop/Projects/Spotify_Proj/Data/MyData/StreamingHistory1.json",
            "/Users/iansnyder/Desktop/Projects/Spotify_Proj/Data/MyData/StreamingHistory2.json",
            "/Users/iansnyder/Desktop/Projects/Spotify_Proj/Data/MyData/StreamingHistory3.json",
        ],
        id="idsnyder136",
    )
# Out:
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["endTime"] = pd.to_datetime(data["endTime"], format="%Y-%m-%d %H:%M")
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["day"] = data["endTime"].dt.strftime("%d")
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["hour"] = data["endTime"].dt.strftime("%H")
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["month"] = data["endTime"].dt.strftime("%m")
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["dm"] = data["endTime"].dt.strftime("%m/%d/%Y")
# /Users/iansnyder/Desktop/Projects/Spotify_Proj/src/UserHistory.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["season"] = data["dm"].apply(get_season)

# %%
print("\n")
print(f"-------Starting Analytics for {test.id}------- \n")
print(f"-------Between 6/2/2022 : 6/3/2023------- \n")
print(f"-------{test.id}'s top 10 artists------- \n")
print(test.get_user_data("artistName"))
# Out:
# -------Starting Analytics for idsnyder136-------
#
# -------Between 6/2/2022 : 6/3/2023-------
#
# -------idsnyder136's top 10 artists-------
#
#                artistName  rank  minutesPlayed
# 456                 Drake   1.0        1134.47
# 576                Future   2.0        1067.44
# 1225            Pop Smoke   3.0         841.31
# 1068         Metro Boomin   4.0         812.28
# 918              Lil Baby   5.0         782.48
# 1623       Treyarch Sound   6.0         636.48
# 1617         Travis Scott   7.0         559.62
# 1518               Tevvez   8.0         512.16
# 823            Kanye West   9.0         508.71
# 934             Lil Wayne  10.0         477.00
# 1099  Motionless In White  11.0         474.25
# 1682    Waka Flocka Flame  12.0         466.59
# 632                Halsey  13.0         440.79
# 1559           The Weeknd  14.0         426.61
# 941           Linkin Park  15.0         419.77
# 7               21 Savage  16.0         393.39
# 134             Bad Bunny  17.0         372.83
# 615            Gucci Mane  18.0         357.46
# 504                Eminem  19.0         356.63
# 846             Key Glock  20.0         343.55

# %%
print("\n")
print(f"-------{test.id}'s top 10 songs------- \n")
print(test.get_user_data("trackName"))
print("\n")
# Out:
# -------idsnyder136's top 10 songs-------
#
#                                            trackName  rank  minutesPlayed
# 25                                               115   1.0         620.74
# 2836                                            Numb   2.0         270.37
# 1563                                 Glimmer of hope   3.0         257.39
# 3454                                    Scholarships   4.0         251.47
# 2973                                            PTSD   5.0         228.47
# 102                                          </c0de>   6.0         219.35
# 1297                                    FEEL NOTHING   7.0         191.28
# 2475                                        Makaveli   8.0         191.12
# 3552                                       Since 6ix   9.0         188.68
# 3269                                     Retaliation  10.0         182.20
# 1519                                        Gasoline  11.0         177.17
# 270                                     Another Life  12.0         176.66
# 1189  EVERY CHANCE I GET (feat. Lil Baby & Lil Durk)  13.0         173.16
# 1383               Find Yourself - Cosmic Gate Remix  14.0         172.52
# 2297         Lights - Bassnectar Remix - Bonus Track  15.0         159.73
# 3851                                        Tell 'Em  16.0         145.81
# 4252                                            WDYW  17.0         144.66
# 2277                                    Life Goes On  18.0         141.22
# 1637              Grove St. Party (feat. Kebo Gotti)  19.0         136.98
# 2864           Oh Okay (feat. Young Thug & Lil Baby)  20.0         134.64

# %%
print(f"-------{test.id}'s Seasonal Breakdown------- \n")
print(f"-------Winter------- \n")
#print(test.get_season_son("winter"))
print(test.get_season_art("spring"))
print("\n")
# Out:
# -------idsnyder136's Seasonal Breakdown-------
#
# -------Winter-------
#
#          artistName  rank  minutesPlayed
# 355          Future   1.0         181.68
# 277           Drake   2.0         134.29
# 549        Lil Baby   3.0         103.30
# 958    Travis Scott   4.0         100.84
# 499      Kanye West   5.0          99.26
# 565     Linkin Park   6.0          98.29
# 720       Pop Smoke   7.0          91.24
# 763         Rihanna   8.0          88.80
# 962  Treyarch Sound   9.0          85.46
# 441          Jaeger  10.0          76.89

# %%
df = test.get_user_data("trackName")
plt.figure(figsize=(10, 6)) # Adjust the size of the plot as needed
sns.barplot(x='minutesPlayed', y="trackName", data=df, palette="Blues_d")
plt.xlabel('Minutes Played')
plt.ylabel('Song')
plt.title(f"{test.id}'s most listened songs from June 2022-June 2023")
plt.show()

# %%
df = test.get_user_data("artistName")
plt.figure(figsize=(10, 6)) # Adjust the size of the plot as needed
sns.barplot(x='minutesPlayed', y='artistName', data=df, palette="Blues_d")
plt.xlabel('Minutes Played')
plt.ylabel('Artist')
plt.title(f"{test.id}'s most listened artists from June 2022-June 2023")
plt.show()
